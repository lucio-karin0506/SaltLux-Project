# %% [markdown]
# ## 2. 트랜잭션 데이터

# %%
import csv
with open('basket.csv', 'r', encoding='utf-8') as cf:
    transactions = []
    r = csv.reader(cf)
    for row in r:
        transactions.append(row)

# %%
transactions
# Out:
# [['소주', '콜라', '와인'],
#  ['소주', '오렌지주스', '콜라'],
#  ['콜라', '맥주', '와인'],
#  ['소주', '콜라', '맥주'],
#  ['오렌지주스', '와인']]

# %% [markdown]
# ## 3. 연관분석

# %% [markdown]
# ### 3.1 연관 규칙 생성

# %%
from apyori import apriori

rules = apriori(transactions, min_support=0.1, min_confidence=0.1)
results = list(rules)
results[0]
# Out:
# RelationRecord(items=frozenset({'맥주'}), support=0.4, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'맥주'}), confidence=0.4, lift=1.0)])

# %%
results[10]
# Out:
# RelationRecord(items=frozenset({'콜라', '소주'}), support=0.6, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'콜라', '소주'}), confidence=0.6, lift=1.0), OrderedStatistic(items_base=frozenset({'소주'}), items_add=frozenset({'콜라'}), confidence=1.0, lift=1.25), OrderedStatistic(items_base=frozenset({'콜라'}), items_add=frozenset({'소주'}), confidence=0.7499999999999999, lift=1.2499999999999998)])

# %% [markdown]
# ### 3.2 연관 규칙 조회

# %%
import pandas as pd

result_df = pd.DataFrame(None, columns=['lhs', 'rhs', 'support', 'confidence', 'lift'])

# %%
index = 0

for result in results:
    support = result[1]
    for ordered_item in result[2]:
        lhs = ','.join(ordered_item[0])
        rhs = ','.join(ordered_item[1])
        confidence = ordered_item[2]
        lift = ordered_item[3]

        result_df.loc[index] = [lhs, rhs, support, confidence, lift]
        index += 1

result_df.head(10)
# Out:
#   lhs    rhs  support  confidence      lift
# 0         맥주      0.4    0.400000  1.000000
# 1         소주      0.6    0.600000  1.000000
# 2      오렌지주스      0.4    0.400000  1.000000
# 3         와인      0.6    0.600000  1.000000
# 4         콜라      0.8    0.800000  1.000000
# 5      맥주,소주      0.2    0.200000  1.000000
# 6  맥주     소주      0.2    0.500000  0.833333
# 7  소주     맥주      0.2    0.333333  0.833333
# 8      맥주,와인      0.2    0.200000  1.000000
# 9  맥주     와인      0.2    0.500000  0.833333

# %% [markdown]
# ### 3.3 연관 규칙 평가

# %%
result_df.loc[(result_df.lhs == '오렌지주스') & (result_df.rhs == '와인')]
# Out:
#       lhs rhs  support  confidence      lift
# 24  오렌지주스  와인      0.2         0.5  0.833333

# %% [markdown]
# ## 4. 뉴스 기사 연관분석 실습

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://fs.jtbc.joins.com/RSS/economy.xml'
news = requests.get(url)
news
# Out:
# <Response [200]>

# %%
news_list = BeautifulSoup(news.content, 'xml')
link_list = news_list.select('item > link')
link_list[0]
# Out:
# <link>https://news.jtbc.joins.com/article/article.aspx?news_id=NB12041654</link>

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
import re
num_pattern = re.compile(r'[0-9]+')

transaction = []
for link in link_list:
    news_link = link.text
    news_link_res = requests.get(news_link)
    news_soup = BeautifulSoup(news_link_res.content, 'html.parser')
    news_content = news_soup.select_one('#articlebody > .article_content')

    news_content_text = news_content.text
    news_content_noun = kkma.nouns(news_content_text)
    news_content_noun = [i for i in news_content_noun if i != '앵커' and i != '기자' and num_pattern.match(i) == None]
    filtered_noun_list = list(filter(lambda word: len(word) > 1, news_content_noun[:70]))

    transaction.append(filtered_noun_list)

transaction
# Out:
# [['미래',
#   '기술',
#   '세계',
#   '최대',
#   '규모',
#   '가전',
#   '가전전시회',
#   '전시회',
#   '미국',
#   '일상',
#   '로봇',
#   '우주',
#   '건강',
#   '관련',
#   '올해',
#   '현지',
#   '김영민',
#   '이곳',
#   '재개',
#   '네바다',
#   '네바다주',
#   '라스',
#   '라스베이거스',
#   '베이',
#   '거스',
#   '프레스',
#   '컨퍼런스',
#   '시작',
#   '기업',
#   '대면',
#   '혼합',
#   '단계',
#   '진화',
#   '지난해',
#   '머스크',
#   '베이조스',
#   '조스',
#   '장자',
#   '우주전쟁',
#   '전쟁',
#   '격화',
#   '우주항공',
#   '항공',
#   '발사대',
#   '필요',
#   '미니',
#   '우주선',
#   '공개',
#   '비행사',
#   '자율',
#   '자율주행',
#   '주행',
#   '모드',
#   '우주정거장',
#   '정거장',
#   '택시',
#   '이동',
#   '회사'],
#  ['종부',
#   '분납',
#   '신청자',
#   '지난해',
#   '종합',
#   '종합부동산세',
#   '부동',
#   '산세',
#   '고지',
#   '사람',
#   '가운데',
#   '명이',
#   '신청',
#   '가량',
#   '종부세액',
#   '세액',
#   '상대적',
#   '납세자',
#   '분석',
#   '현대',
#   '현대차',
#   '기아',
#   '미국',
#   '역대',
#   '최다',
#   '판매',
#   '판매현대차',
#   '대차',
#   '시장',
#   '기록',
#   '진출',
#   '처음',
#   '연간',
#   '판매량',
#   '일본',
#   '혼다',
#   '카페',
#   '일회용',
#   '사용',
#   '금지',
#   '금지카페',
#   '플라스틱',
#   '플라스틱컵',
#   '코로나',
#   '때문',
#   '일시적',
#   '허용',
#   '규제',
#   '일회용품',
#   '용품',
#   '품목',
#   '적용',
#   '업종',
#   '종이컵'],
#  ['세상',
#   '세계',
#   '최대',
#   '가전',
#   '전시회',
#   '내일',
#   '개막',
#   '우주',
#   '로봇',
#   '건강',
#   '관련',
#   '기술',
#   '미국',
#   '김영민',
#   '이곳',
#   '재개',
#   '네바다',
#   '네바다주',
#   '라스',
#   '라스베이거스',
#   '베이',
#   '거스',
#   '오늘',
#   '프레스',
#   '컨퍼런스',
#   '시작',
#   '기업',
#   '대면',
#   '혼합',
#   '단계',
#   '진화',
#   '미래',
#   '지난해',
#   '머스크',
#   '베이조스',
#   '조스',
#   '장자',
#   '우주전쟁',
#   '전쟁',
#   '올해',
#   '격화',
#   '우주항공',
#   '항공',
#   '발사대',
#   '필요',
#   '미니',
#   '우주선',
#   '공개',
#   '비행사',
#   '자율',
#   '자율주행',
#   '주행',
#   '모드',
#   '우주정거장',
#   '정거장',
#   '택시'],
#  ['인용',
#   '인용보도',
#   '보도',
#   '프로그램',
#   '프로그램명',
#   '아침',
#   '저작권',
#   '방송',
#   '진행',
#   '이정',
#   '올해',
#   '부동산',
#   '시장',
#   '예측',
#   '평가',
#   '이번',
#   '기준',
#   '기준금리',
#   '금리',
#   '추가',
#   '인상',
#   '예고',
#   '가계',
#   '가계대출',
#   '대출',
#   '규제',
#   '강화',
#   '전망',
#   '무엇',
#   '변수',
#   '대통령',
#   '선거',
#   '불확실',
#   '권대중',
#   '대중',
#   '명지대',
#   '지대',
#   '부동산학과',
#   '학과',
#   '교수',
#   '안녕',
#   '기간',
#   '고공',
#   '고공행진',
#   '행진',
#   '집값',
#   '요즘',
#   '모습',
#   '안정',
#   '지금',
#   '상승세',
#   '둔화',
#   '분명',
#   '마이너스',
#   '서울',
#   '경우'],
#  ['쌍용',
#   '쌍용자동차',
#   '자동차',
#   '에디슨',
#   '에디슨모터스',
#   '모터스',
#   '인수',
#   '원대',
#   '매출',
#   '중소기업',
#   '회사',
#   '만큼',
#   '시장',
#   '관심',
#   '다음',
#   '주가',
#   '본계약',
#   '지금',
#   '일정',
#   '조달',
#   '우려',
#   '주식',
#   '주식시장',
#   '먹튀',
#   '논란',
#   '정아람',
#   '아람',
#   '어제',
#   '관계',
#   '관계사인',
#   '사인',
#   '마감',
#   '쌍용차',
#   '구성',
#   '컨소시엄',
#   '마련',
#   '사모',
#   '사모펀드',
#   '펀드',
#   '투자',
#   '보류',
#   '소식',
#   '악재',
#   '작용',
#   '호재',
#   '지난해',
#   '이후',
#   '계속',
#   '내림세',
#   '주인',
#   '정상화',
#   '희망',
#   '주주',
#   '책임'],
#  ['인도네시아',
#   '석탄',
#   '제한',
#   '우려',
#   '현실화',
#   '현실화세계',
#   '세계',
#   '최대',
#   '수출국',
#   '자국',
#   '발전소',
#   '이달',
#   '동안',
#   '수출',
#   '당장',
#   '수입국',
#   '중국',
#   '건물',
#   '가격',
#   '가까이',
#   '급등',
#   '장기화',
#   '불안',
#   '임원',
#   '방사',
#   '방사청',
#   '출신',
#   '인사',
#   '내정',
#   '국자산관리공사',
#   '자산',
#   '관리',
#   '공사',
#   '방위',
#   '방위사업',
#   '사업',
#   '금융',
#   '금융노조',
#   '노조',
#   '반발',
#   '다음',
#   '주주',
#   '주주총회',
#   '총회',
#   '확정',
#   '경력',
#   '경력상',
#   '적합',
#   '인물',
#   '낙하산',
#   '전횡',
#   '중지하',
#   '주장',
#   '개막',
#   '한국',
#   '기업',
#   '총출동',
#   '총출동세계',
#   '전자',
#   '전시회',
#   '미국'],
#  ['머리',
#   '흰머리',
#   '갈색',
#   '샴푸',
#   '논란',
#   '식약처가',
#   '처가',
#   '성분',
#   '문제',
#   '제동',
#   '개발',
#   '개발자인',
#   '자인',
#   '카이스트',
#   '이스트',
#   '제조',
#   '제조업체',
#   '업체',
#   '신기술',
#   '기술',
#   '지원하긴',
#   '규제',
#   '반발',
#   '원석',
#   '취재',
#   '지난달',
#   '식품',
#   '식품의약품안전처',
#   '의약품',
#   '안전',
#   '화장품',
#   '원료',
#   '지정',
#   '염색약',
#   '염료',
#   '머리카락',
#   '촉진',
#   '역할',
#   '식약처',
#   '피부염',
#   '평가',
#   '유럽',
#   '사용',
#   '금지',
#   '고려',
#   '최근',
#   '인기',
#   '염색',
#   '중소기업',
#   '우리',
#   '겨냥',
#   '조치',
#   '때문',
#   '코팅',
#   '사과',
#   '원리',
#   '착안'],
#  ['이번',
#   '저희',
#   '취재',
#   '소식',
#   '방역',
#   '방역조치',
#   '조치',
#   '손실',
#   '매출',
#   '가게',
#   '보상금',
#   '기준',
#   '논란',
#   '반발',
#   '정부',
#   '보상',
#   '대상',
#   '포함',
#   '방안',
#   '검토',
#   '움직임',
#   '자영',
#   '자영업자',
#   '업자',
#   '집단',
#   '휴업',
#   '장서',
#   '장서윤',
#   '한때',
#   '고깃집',
#   '코로나',
#   '코로나19',
#   '이후',
#   '반토막',
#   '토막',
#   '직원',
#   '수천만',
#   '적자',
#   '연평균',
#   '이유',
#   '손실보상금',
#   '운영',
#   '인천',
#   '문학',
#   '문학동',
#   '장사',
#   '규모',
#   '피해',
#   '제외',
#   '평균',
#   '현재'],
#  ['고래',
#   '새우',
#   '에디슨',
#   '에디슨모터스',
#   '모터스',
#   '쌍용',
#   '쌍용자동차',
#   '자동차',
#   '인수',
#   '자금',
#   '대기',
#   '사모',
#   '사모펀드',
#   '펀드',
#   '투자',
#   '보류',
#   '때문',
#   '호재',
#   '주가',
#   '의심',
#   '아람',
#   '오늘',
#   '관계',
#   '관계사인',
#   '사인',
#   '어제',
#   '마감',
#   '쌍용차',
#   '구성',
#   '컨소시엄',
#   '마련',
#   '소식',
#   '악재',
#   '작용',
#   '지난해',
#   '대까지',
#   '이후',
#   '계속',
#   '내림세',
#   '주인',
#   '정상화',
#   '희망',
#   '주주',
#   '책임',
#   '자세',
#   '요구',
#   '주식',
#   '투자자',
#   '지가',
#   '이슈',
#   '사실',
#   '시장',
#   '긍정적'],
#  ['직구',
#   '배송',
#   '배송대행업체',
#   '대행',
#   '업체',
#   '카드',
#   '정보',
#   '유출',
#   '유출유명',
#   '유명',
#   '해외',
#   '해외직구',
#   '신용',
#   '신용카드',
#   '등록',
#   '이후',
#   '이용',
#   '가맹점',
#   '결제',
#   '승인',
#   '피해',
#   '카드사',
#   '이곳',
#   '이력',
#   '고객',
#   '상대',
#   '대응',
#   '방법',
#   '안내',
#   '평소',
#   '차단',
#   '부정',
#   '사용',
#   '설명',
#   '하나',
#   '하나은행',
#   '은행',
#   '희망',
#   '희망퇴직',
#   '퇴직',
#   '만40세',
#   '대상',
#   '대상시중은행',
#   '시중',
#   '새해',
#   '신청',
#   '시작',
#   '연령',
#   '경우',
#   '지난해',
#   '역대',
#   '역대급',
#   '실적',
#   '조건',
#   '신청자',
#   '아시아',
#   '에어',
#   '에어서울',
#   '서울',
#   '운항',
#   '연기',
#   '연기오미크론',
#   '오미크론'],
#  ['드라마',
#   '년대',
#   '추억',
#   '명소',
#   '서울',
#   '종로',
#   '패스트푸드',
#   '코로나',
#   '코로나19',
#   '충격',
#   '저희',
#   '현장',
#   '상점',
#   '건너',
#   '효정',
#   '간판',
#   '자리',
#   '햄버거',
#   '주방',
#   '오늘',
#   '국내',
#   '모습',
#   '점포',
#   '연지',
#   '관계자',
#   '그전',
#   '상권',
#   '영향',
#   '노후',
#   '비용',
#   '유지',
#   '유지보수',
#   '보수',
#   '문제',
#   '이곳',
#   '그동안',
#   '대표적',
#   '약속',
#   '장소',
#   '유명',
#   '소개팅',
#   '장면',
#   '정도',
#   '상징',
#   '길어지',
#   '어지',
#   '사태',
#   '손님',
#   '외출',
#   '시민',
#   '외국인',
#   '관광객',
#   '때문',
#   '한국',
#   '한국부동산원',
#   '부동',
#   '산원'],
#  ['회삿돈',
#   '시점',
#   '이씨',
#   '상장사',
#   '주식',
#   '원어치',
#   '어치',
#   '때문',
#   '슈퍼',
#   '개미',
#   '유명세',
#   '명세',
#   '투자',
#   '내역',
#   '누구',
#   '공시',
#   '회사',
#   '누리',
#   '지난해',
#   '반도체',
#   '관련',
#   '지분',
#   '지분율',
#   '주요',
#   '주주',
#   '금융',
#   '금융감독원',
#   '감독원',
#   '전자',
#   '전자공시시스템',
#   '시스템',
#   '실명',
#   '주소지',
#   '경기',
#   '경기도',
#   '파주',
#   '기준',
#   '주식시장',
#   '시장',
#   '파주',
#   '슈퍼개미',
#   '별칭',
#   '시작',
#   '가격',
#   '손실'],
#  ['조치',
#   '고속',
#   '고속도로',
#   '도로',
#   '운전',
#   '차량',
#   '물건',
#   '다가',
#   '사고',
#   '그동안',
#   '가해',
#   '보상',
#   '올해',
#   '국가',
#   '효정',
#   '나무',
#   '충격',
#   '보닛',
#   '종잇장',
#   '낙하',
#   '피해자',
#   '정도',
#   '사진',
#   '앞유리',
#   '유리',
#   '강타',
#   '버스',
#   '갓길',
#   '너머',
#   '대형',
#   '포대',
#   '포대자루',
#   '자루',
#   '증가',
#   '이것',
#   '책임',
#   '관할',
#   '지자체',
#   '민간',
#   '국토',
#   '국토부와',
#   '부와',
#   '금융',
#   '금융위',
#   '관련',
#   '규정',
#   '자동차',
#   '보험',
#   '지금',
#   '부부',
#   '특약',
#   '가입',
#   '운전자'],
#  ['서울',
#   '서울사랑상품권',
#   '사랑',
#   '상품권',
#   '발행',
#   '발행설',
#   '명절',
#   '서울시',
#   '자치구',
#   '골목',
#   '골목상권',
#   '상권',
#   '활성화',
#   '규모',
#   '일정',
#   '한도',
#   '할인',
#   '금액',
#   '구매',
#   '지난해',
#   '아파트',
#   '역대',
#   '역대급',
#   '거래',
#   '거래절벽',
#   '절벽',
#   '거래량',
#   '최저',
#   '기록',
#   '신고',
#   '절반',
#   '수준',
#   '아파트값',
#   '시기',
#   '집값',
#   '불황',
#   '불황형',
#   '상승',
#   '지난달',
#   '외식',
#   '외식물가',
#   '물가',
#   '최고',
#   '최고지난달',
#   '상승률',
#   '품목',
#   '가운데',
#   '커피'],
#  ['고속도로',
#   '낙하',
#   '사고',
#   '경우',
#   '지금',
#   '가해',
#   '가해차량',
#   '차량',
#   '피해',
#   '보상',
#   '올해',
#   '국가',
#   '효정',
#   '새해',
#   '자동차',
#   '보험',
#   '소식',
#   '나무',
#   '충격',
#   '보닛',
#   '종잇장',
#   '피해자',
#   '정도',
#   '사진',
#   '앞유리',
#   '유리',
#   '강타',
#   '버스',
#   '갓길',
#   '너머',
#   '대형',
#   '포대',
#   '포대자루',
#   '자루',
#   '증가',
#   '이것',
#   '치우',
#   '치우운',
#   '책임',
#   '도로',
#   '관할',
#   '지자체',
#   '민간',
#   '국토',
#   '국토부와',
#   '부와',
#   '금융',
#   '금융위',
#   '관련',
#   '규정',
#   '부부',
#   '특약',
#   '가입',
#   '운전자',
#   '배우자',
#   '운전'],
#  ['지난해',
#   '외식',
#   '외식물가',
#   '물가',
#   '상승률',
#   '통계청',
#   '기간',
#   '개월',
#   '갈비탕',
#   '김밥',
#   '조사',
#   '품목',
#   '커피',
#   '유일'],
#  ['전자',
#   '전자업계',
#   '업계',
#   '최신',
#   '트렌드',
#   '세계',
#   '최대',
#   '전자제품',
#   '자제품',
#   '제품',
#   '전시회',
#   '온라인',
#   '현장',
#   '개최',
#   '다음',
#   '신기술',
#   '기술',
#   '우리',
#   '김영민',
#   '미국',
#   '라스',
#   '라스베이거스',
#   '베이',
#   '거스',
#   '최근',
#   '가전',
#   '성격',
#   '로봇',
#   '전기',
#   '전기차',
#   '스마트',
#   '스마트홈',
#   '첨단',
#   '경연',
#   '올해',
#   '기업',
#   '참가',
#   '규모',
#   '번째',
#   '갈등',
#   '중국',
#   '모양',
#   '인공',
#   '인공지능',
#   '지능',
#   '삼성',
#   '삼성전자',
#   '공개',
#   '영상',
#   '외계인',
#   '등장'],
#  ['새해',
#   '신용',
#   '신용정보',
#   '정보',
#   '방식',
#   '데이터',
#   '예금',
#   '카드',
#   '주식',
#   '보험',
#   '내역',
#   '모든',
#   '인터넷',
#   '오기',
#   '금지',
#   '서비스',
#   '재테크',
#   '경제',
#   '구희',
#   '구희령',
#   '스타',
#   '광고',
#   '경품',
#   '무엇',
#   '은행',
#   '카드사',
#   '증권사',
#   '보험사',
#   '등에',
#   '이것',
#   '대로',
#   '관리',
#   '소비자',
#   '마이',
#   '마이데이터',
#   '수십',
#   '수십개',
#   '업체',
#   '저희',
#   '고객',
#   '주시',
#   '경쟁',
#   '시범',
#   '이재',
#   '이재승',
#   '회사원',
#   '금융권',
#   '앱들',
#   '확인',
#   '한눈',
#   '장점',
#   '입사',
#   '개월'],
#  ['지난해',
#   '우리',
#   '우리나라',
#   '나라',
#   '수출',
#   '전년',
#   '기간',
#   '달러',
#   '달러',
#   '역대',
#   '최고',
#   '수입액',
#   '처음',
#   '전체',
#   '무역액',
#   '세계',
#   '규모'],
#  ['횟감',
#   '광어',
#   '우럭',
#   '요즘',
#   '메뉴판',
#   '횟집',
#   '도맷값',
#   '손님',
#   '팔기',
#   '먹거리',
#   '먹거리값',
#   '기름값',
#   '이달',
#   '소비자',
#   '소비자물가',
#   '물가',
#   '효정',
#   '노량진',
#   '장정열',
#   '정열',
#   '장사',
#   '올해',
#   '상황',
#   '처음',
#   '국민',
#   '몸값',
#   '상승',
#   '노량진수산시장',
#   '수산',
#   '시장',
#   '상인',
#   '이례적',
#   '평상시',
#   '이번',
#   '지난해',
#   '우럭',
#   '마리',
#   '오늘',
#   '어치',
#   '사면',
#   '매운탕',
#   '서비스',
#   '지금',
#   '수가',
#   '지난달',
#   '도매',
#   '가격',
#   '광어값',
#   '도매가',
#   '전년']]

# %%
from apyori import apriori

rules = apriori(transaction, min_support=0.2, min_confidence=0.2)
results = list(rules)
results[0]
# Out:
# RelationRecord(items=frozenset({'관련'}), support=0.25, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'관련'}), confidence=0.25, lift=1.0)])

# %%
import pandas as pd

result_df = pd.DataFrame(None, columns=['lhs', 'rhs', 'support', 'confidence', 'lift'])
index = 0

for res in results:
    support = res[1]
    ordered_item = res[2]
    for item in ordered_item:
        lhs = ','.join(item[0])
        rhs = ','.join(item[1])
        confidence = item[2]
        lift = item[3]

        result_df.loc[index] = [lhs, rhs, support, confidence, lift]
        index += 1

result_df
# Out:
#               lhs  rhs  support  confidence  lift
# 0                   관련     0.25        0.25   1.0
# 1                   규모     0.25        0.25   1.0
# 2                   금융     0.20        0.20   1.0
# 3                   기술     0.20        0.20   1.0
# 4                   기업     0.20        0.20   1.0
# ..            ...  ...      ...         ...   ...
# 245  미국,기업,세계,전시회   최대     0.20        1.00   5.0
# 246   미국,기업,세계,최대  전시회     0.20        1.00   5.0
# 247  최대,미국,기업,전시회   세계     0.20        1.00   4.0
# 248  최대,기업,세계,전시회   미국     0.20        1.00   4.0
# 249  최대,미국,세계,전시회   기업     0.20        1.00   5.0
#
# [250 rows x 5 columns]

# %%
result_df[result_df['lhs'] == ''].sort_values('support', ascending=False).head(10)
# Out:
#    lhs     rhs  support  confidence  lift
# 22         지난해     0.55        0.55   1.0
# 14          올해     0.35        0.35   1.0
# 11          시장     0.30        0.30   1.0
# 0           관련     0.25        0.25   1.0
# 21          지금     0.25        0.25   1.0
# 1           규모     0.25        0.25   1.0
# 5           때문     0.25        0.25   1.0
# 6           미국     0.25        0.25   1.0
# 59      시장,지난해     0.25        0.25   1.0
# 8           세계     0.25        0.25   1.0

# %%
result_df[result_df.lhs.str.contains('미국')].sort_values('lift', ascending=False)
# Out:
#            lhs        rhs  support  confidence  lift
# 168      미국,최대      기업,세계      0.2         1.0   5.0
# 164      미국,기업      세계,최대      0.2         1.0   5.0
# 170   미국,기업,세계         최대      0.2         1.0   5.0
# 173   미국,세계,최대         기업      0.2         1.0   5.0
# 179      미국,기업     전시회,최대      0.2         1.0   5.0
# ..         ...        ...      ...         ...   ...
# 176         미국  기업,전시회,최대      0.2         0.8   4.0
# 171   미국,기업,최대         세계      0.2         1.0   4.0
# 156  미국,기업,전시회         세계      0.2         1.0   4.0
# 31          미국         기업      0.2         0.8   4.0
# 42          미국         세계      0.2         0.8   3.2
#
# [65 rows x 5 columns]

# %% [markdown]
# ## 5. 연습문제

# %%
import csv
with open('mybasket.csv', 'r', encoding='utf-8') as file:
    file_content = csv.reader(file)
    content_list = []
    for row in file_content:
        content_list.append(row)

content_list[:5]
# Out:
# [['clothes', 'frozen', 'snack'],
#  ['frozen', 'toiletry'],
#  ['clothes', 'alcohol', 'toiletry', 'snack'],
#  ['clothes', 'milk', 'bakery'],
#  ['clothes']]

# %%
# 전체 트랜잭션 개수
len(content_list)
# Out:
# 786

# %%
# 규칙 순서 상관없이 최소 지지도, 신뢰도 각각 10% 일 경우 규칙 수
from apyori import apriori

res = apriori(content_list, min_support=0.1, min_confidence=0.1)
result = list(res)
len(result)
# Out:
# 53

# %%
# 순서 있는 전체 연관 규칙 출력
filtered_res = []

for item in result:
    ordered_items = item[2]
    for ordered_item in ordered_items:
        if ordered_item[0] != '' and ordered_item[1] != '':
            filtered_res.append(item)

len(filtered_res)
# Out:
# 269

# %%
# 향상도가 가장 높은 연관 규칙
result_df = pd.DataFrame(None, columns=['lhs', 'rhs', 'support', 'confidence', 'lift'])
index = 0

for res in filtered_res:
    support = res[1]
    ordered_item = res[2]
    for item in ordered_item:
        lhs = ','.join(item[0])
        rhs = ','.join(item[1])
        confidence = item[2]
        lift = item[3]

        result_df.loc[index] = [lhs, rhs, support, confidence, lift]
        index += 1

max_lift = result_df['lift'].max()
result_df[result_df['lift'] == max_lift][['lhs', 'rhs', 'lift']]
# Out:
#              lhs          rhs      lift
# 934         milk  bakery,deco  2.343877
# 935  bakery,deco         milk  2.343877
# 941         milk  bakery,deco  2.343877
# 942  bakery,deco         milk  2.343877
# 948         milk  bakery,deco  2.343877
# 949  bakery,deco         milk  2.343877
# 955         milk  bakery,deco  2.343877
# 956  bakery,deco         milk  2.343877
# 962         milk  bakery,deco  2.343877
# 963  bakery,deco         milk  2.343877
# 969         milk  bakery,deco  2.343877
# 970  bakery,deco         milk  2.343877
# 976         milk  bakery,deco  2.343877
# 977  bakery,deco         milk  2.343877

# %%
# 가장 많이 팔린 두 제품
a = result_df.loc[result_df.lhs == ''].sort_values('support', ascending=False).iloc[:2]['rhs'].values
two_top_sold = ', '.join(a)
two_top_sold
# Out:
# 'clothes, snack'

# %%
# 가장 많이 팔린 두 제품 사이의 지지도, 신뢰도, 향상도
a = result_df[(result_df.lhs.str.contains('clothes')) & (result_df.rhs == 'snack')][['support', 'confidence', 'lift']]
a.sort_values('lift', ascending=False)
# Out:
#        support  confidence      lift
# 1945  0.101781    0.695652  1.465905
# 1840  0.101781    0.695652  1.465905
# 1735  0.101781    0.695652  1.465905
# 1750  0.101781    0.695652  1.465905
# 1765  0.101781    0.695652  1.465905
# 1780  0.101781    0.695652  1.465905
# 1795  0.101781    0.695652  1.465905
# 1810  0.101781    0.695652  1.465905
# 1825  0.101781    0.695652  1.465905
# 1855  0.101781    0.695652  1.465905
# 1870  0.101781    0.695652  1.465905
# 1885  0.101781    0.695652  1.465905
# 1900  0.101781    0.695652  1.465905
# 1915  0.101781    0.695652  1.465905
# 1930  0.101781    0.695652  1.465905
# 1145  0.138677    0.641176  1.351112
# 1166  0.138677    0.641176  1.351112
# 1159  0.138677    0.641176  1.351112
# 1152  0.138677    0.641176  1.351112
# 1173  0.138677    0.641176  1.351112
# 1138  0.138677    0.641176  1.351112
# 1131  0.138677    0.641176  1.351112
# 536   0.136132    0.636905  1.342110
# 494   0.136132    0.636905  1.342110
# 501   0.136132    0.636905  1.342110
# 508   0.136132    0.636905  1.342110
# 515   0.136132    0.636905  1.342110
# 522   0.136132    0.636905  1.342110
# 529   0.136132    0.636905  1.342110
# 1180  0.128499    0.604790  1.274438
# 1187  0.128499    0.604790  1.274438
# 1194  0.128499    0.604790  1.274438
# 1201  0.128499    0.604790  1.274438
# 1208  0.128499    0.604790  1.274438
# 1215  0.128499    0.604790  1.274438
# 1222  0.128499    0.604790  1.274438
# 858   0.147583    0.577114  1.216118
# 837   0.147583    0.577114  1.216118
# 844   0.147583    0.577114  1.216118
# 851   0.147583    0.577114  1.216118
# 865   0.147583    0.577114  1.216118
# 872   0.147583    0.577114  1.216118
# 879   0.147583    0.577114  1.216118
# 137   0.244275    0.497409  1.048160
# 140   0.244275    0.497409  1.048160
# 134   0.244275    0.497409  1.048160
