# %% [markdown]
# ## 1. 텍스트 마이닝

# %% [markdown]
# ## 2. NLTK 자연어처리기

# %% [markdown]
# ### 2.1 말뭉치(Corpus)

# %%
import nltk
# nltk.download()
# download direct to c directory

# %%
from nltk.corpus import treebank
print(treebank.fileids())
# Out:
# ['wsj_0001.mrg', 'wsj_0002.mrg', 'wsj_0003.mrg', 'wsj_0004.mrg', 'wsj_0005.mrg', 'wsj_0006.mrg', 'wsj_0007.mrg', 'wsj_0008.mrg', 'wsj_0009.mrg', 'wsj_0010.mrg', 'wsj_0011.mrg', 'wsj_0012.mrg', 'wsj_0013.mrg', 'wsj_0014.mrg', 'wsj_0015.mrg', 'wsj_0016.mrg', 'wsj_0017.mrg', 'wsj_0018.mrg', 'wsj_0019.mrg', 'wsj_0020.mrg', 'wsj_0021.mrg', 'wsj_0022.mrg', 'wsj_0023.mrg', 'wsj_0024.mrg', 'wsj_0025.mrg', 'wsj_0026.mrg', 'wsj_0027.mrg', 'wsj_0028.mrg', 'wsj_0029.mrg', 'wsj_0030.mrg', 'wsj_0031.mrg', 'wsj_0032.mrg', 'wsj_0033.mrg', 'wsj_0034.mrg', 'wsj_0035.mrg', 'wsj_0036.mrg', 'wsj_0037.mrg', 'wsj_0038.mrg', 'wsj_0039.mrg', 'wsj_0040.mrg', 'wsj_0041.mrg', 'wsj_0042.mrg', 'wsj_0043.mrg', 'wsj_0044.mrg', 'wsj_0045.mrg', 'wsj_0046.mrg', 'wsj_0047.mrg', 'wsj_0048.mrg', 'wsj_0049.mrg', 'wsj_0050.mrg', 'wsj_0051.mrg', 'wsj_0052.mrg', 'wsj_0053.mrg', 'wsj_0054.mrg', 'wsj_0055.mrg', 'wsj_0056.mrg', 'wsj_0057.mrg', 'wsj_0058.mrg', 'wsj_0059.mrg', 'wsj_0060.mrg', 'wsj_0061.mrg', 'wsj_0062.mrg', 'wsj_
# ...

# %%
wsj_0001 = treebank.sents('wsj_0001.mrg')

# %%
for line in wsj_0001:
    print(' '.join(line))
# Out:
# Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# Mr. Vinken is chairman of Elsevier N.V. , the Dutch publishing group .

# %%
# 형태소 출력
treebank.tagged_words('wsj_0001.mrg') # 품사태깅 => 품사가 부착된 단어-품사 리스트
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
print(treebank.parsed_sents('wsj_0001.mrg')[0])
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %%
# book 데이터
# nltk.download('book', quiet=True)

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
print(type(text1))
print(text1)
# Out:
# <class 'nltk.text.Text'>
# <Text: Moby Dick by Herman Melville 1851>

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
print(emma[:500])
print(len(emma))
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.
#
# She was the youngest of the two daughters of a most affectionate,
# indulgent father; and had, in consequence of her sister's marriage,
# been mistress of his house from a very early period.  Her mother
# had died t
# 887071

# %% [markdown]
# ### 2.2 토큰 생성(Tokenizing)

# %%
# 토큰 생성
from nltk.tokenize import sent_tokenize, word_tokenize

emma_sample = emma[:500]
sentence_list = sent_tokenize(emma_sample)
print(sentence_list)
# Out:
# ['[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.', "She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.", 'Her mother\nhad died t']

# %%
word_list = word_tokenize(emma_sample)
print(word_list)
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER', 'I', 'Emma', 'Woodhouse', ',', 'handsome', ',', 'clever', ',', 'and', 'rich', ',', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', ',', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', ';', 'and', 'had', 'lived', 'nearly', 'twenty-one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', '.', 'She', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate', ',', 'indulgent', 'father', ';', 'and', 'had', ',', 'in', 'consequence', 'of', 'her', 'sister', "'s", 'marriage', ',', 'been', 'mistress', 'of', 'his', 'house', 'from', 'a', 'very', 'early', 'period', '.', 'Her', 'mother', 'had', 'died', 't']

# %%
from nltk.tokenize import RegexpTokenizer

ret = RegexpTokenizer('[\w]{2,}')
print(ret.tokenize(emma_sample))
# Out:
# ['Emma', 'by', 'Jane', 'Austen', '1816', 'VOLUME', 'CHAPTER', 'Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', 'She', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'most', 'affectionate', 'indulgent', 'father', 'and', 'had', 'in', 'consequence', 'of', 'her', 'sister', 'marriage', 'been', 'mistress', 'of', 'his', 'house', 'from', 'very', 'early', 'period', 'Her', 'mother', 'had', 'died']

# %% [markdown]
# ### 2.3 형태소 분석

# %%
# 형태소 분석
# 1. 어근 추출 => stemming
words = ['sending', 'cooking', 'flies', 'lives', 'crying', 'dying']

# 접미사 제거
from nltk.stem import PorterStemmer

pst = PorterStemmer()
[pst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'live', 'cri', 'die']

# %%
from nltk.stem import LancasterStemmer

lst = LancasterStemmer()
[lst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'liv', 'cry', 'dying']

# %%
from nltk.stem.regexp import RegexpStemmer

rest = RegexpStemmer('ing')
[rest.stem(w) for w in words]
# Out:
# ['send', 'cook', 'flies', 'lives', 'cry', 'dy']

# %%
words2 = ['enviar', 'cocina', 'moscas', 'vidas', 'llorar', 'morir']

from nltk.stem.snowball import SnowballStemmer

sbst = SnowballStemmer('spanish')
[sbst.stem(w) for w in words2]
# Out:
# ['envi', 'cocin', 'mosc', 'vid', 'llor', 'mor']

# %%
# 2. 원형 복원(Lemmatizing)
words3 = ['cooking', 'believes']

from nltk.stem.wordnet import WordNetLemmatizer

w1 = WordNetLemmatizer()
[w1.lemmatize(w) for w in words3]
# Out:
# ['cooking', 'belief']

# %%
# 동사 탐색
[w1.lemmatize(w, pos='v') for w in words3]
# Out:
# ['cook', 'believe']

# %%
# 3. 품사 태깅 (POS Tagging)
# 품사에 대한 설명
nltk.help.upenn_tagset('NNP')
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %%
# 단어에 품사를 포함한 튜플들을 리스트로 반환
sentence = emma[50:289]
print(sentence)
# Out:
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.

# %%
from nltk.tag import pos_tag
from nltk.tokenize import RegexpTokenizer

ret = RegexpTokenizer('[\w]{2,}')
tagged_list = pos_tag(ret.tokenize(sentence))

print(tagged_list)
# Out:
# [('Emma', 'NNP'), ('Woodhouse', 'NNP'), ('handsome', 'VBD'), ('clever', 'NN'), ('and', 'CC'), ('rich', 'JJ'), ('with', 'IN'), ('comfortable', 'JJ'), ('home', 'NN'), ('and', 'CC'), ('happy', 'JJ'), ('disposition', 'NN'), ('seemed', 'VBD'), ('to', 'TO'), ('unite', 'VB'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('blessings', 'NNS'), ('of', 'IN'), ('existence', 'NN'), ('and', 'CC'), ('had', 'VBD'), ('lived', 'VBN'), ('nearly', 'RB'), ('twenty', 'JJ'), ('one', 'CD'), ('years', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('with', 'IN'), ('very', 'RB'), ('little', 'JJ'), ('to', 'TO'), ('distress', 'VB'), ('or', 'CC'), ('vex', 'VB'), ('her', 'PRP$')]

# %%
# 형태소가 명사인 것만 출력
nouns_list = [t[0] for t in tagged_list if t[1] == 'NN']
nouns_list
# Out:
# ['clever', 'home', 'disposition', 'existence', 'world']

# %%
# NN, NNP, NNS => 모든 명사 탐색
import re

pattern = re.compile('NN?')
nouns_list = [t[0] for t in tagged_list if pattern.match(t[1])]

print(nouns_list)
# Out:
# ['Emma', 'Woodhouse', 'clever', 'home', 'disposition', 'blessings', 'existence', 'years', 'world']

# %%
# 품사 제거한 단어들의 리스트 얻음
from nltk.tag import untag

print(untag(tagged_list))
# Out:
# ['Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'comfortable', 'home', 'and', 'happy', 'disposition', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', 'and', 'had', 'lived', 'nearly', 'twenty', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her']

# %%
# 원래의 단어와 품사 붙여 새로운 토큰 이름 생성
# 철자 같고 품사 다른 단어 구분 위함
print(['/'.join(p) for p in tagged_list])
# Out:
# ['Emma/NNP', 'Woodhouse/NNP', 'handsome/VBD', 'clever/NN', 'and/CC', 'rich/JJ', 'with/IN', 'comfortable/JJ', 'home/NN', 'and/CC', 'happy/JJ', 'disposition/NN', 'seemed/VBD', 'to/TO', 'unite/VB', 'some/DT', 'of/IN', 'the/DT', 'best/JJS', 'blessings/NNS', 'of/IN', 'existence/NN', 'and/CC', 'had/VBD', 'lived/VBN', 'nearly/RB', 'twenty/JJ', 'one/CD', 'years/NNS', 'in/IN', 'the/DT', 'world/NN', 'with/IN', 'very/RB', 'little/JJ', 'to/TO', 'distress/VB', 'or/CC', 'vex/VB', 'her/PRP$']

# %% [markdown]
# ### 2.4 Text 클래스

# %%
import nltk

emma = nltk.corpus.gutenberg.raw('austen-emma.txt')

# %%
from nltk.tokenize import RegexpTokenizer

ret = RegexpTokenizer('[\w]+')

# %%
from nltk import Text

emma_text = Text(ret.tokenize(emma))

# %%
emma_text.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# 해당 단어가 들어간 문장 탐색
emma_text.concordance('Emma', lines=5)
# Out:
# Displaying 5 of 865 matches:
#  Emma by Jane Austen 1816 VOLUME I CHAPTER
#  Jane Austen 1816 VOLUME I CHAPTER I Emma Woodhouse handsome clever and rich w
# f both daughters but particularly of Emma Between _them_ it was more the intim
# nd friend very mutually attached and Emma doing just what she liked highly est
#  by her own The real evils indeed of Emma s situation were the power of having

# %%
# 문맥에서 비슷한 단어 탐색
emma_text.similar('general', 10)
# Out:
# love short it london time fact her which highbury and

# %%
# 둘 이상의 단어에 의해 공유되는 문맥 조사
emma_text.common_contexts(['general', 'strong'])
# Out:
# a_expectation

# %%
# 같이 붙어서 쓰이는 단어, 연어를 주어진 인수 개수만큼 탐색
emma_text.collocations(10)
# Out:
# Mrs Weston; Frank Churchill; Miss Woodhouse; Mrs Elton; Miss Bates;
# Jane Fairfax; Miss Fairfax; every thing; young man; every body

# %%
# 처음부터 지정한 단어가 얼마나 많이 나타날지 단어의 위치 표시
emma_text.dispersion_plot(["Emma", "Knightley", "Frank", "Jane", "Harriet", "Robert"])

# %%
# 단어 전체 개수 계산
print(len(emma_text))

# 중복 제거한 단어 수
print(len(set(emma_text)))

# 텍스트의 어휘 풍부성에 대한 척도 계산
print(len(set(emma_text)) / len(emma_text))
# Out:
# 161983
# 7723
# 0.047677842736583466

# %% [markdown]
# ### 2.5 FreqDist 클래스

# %%
# 문서에 사용된 단어 또는 토큰의 사용 빈도 정보 담는 클래스
emma_fd = emma_text.vocab()
type(emma_fd)
# Out:
# nltk.probability.FreqDist

# %%
from nltk.tag import pos_tag
from nltk import FreqDist

stopwords = ["Mr.", "Mrs.", "Miss", "Mr", "Mrs", "Dear"]

emma_tokens = pos_tag(emma_text)
names_list = [t[0] for t in emma_tokens if t[1] == 'NNP' and t[0] not in stopwords]
emma_fd_names = FreqDist(names_list)

emma_fd_names
# Out:
# FreqDist({'Emma': 830, 'Harriet': 491, 'Weston': 439, 'Knightley': 389, 'Elton': 385, 'Woodhouse': 304, 'Jane': 299, 'Fairfax': 241, 'Churchill': 223, 'Frank': 208, ...})

# %%
emma_fd_names.N(), emma_fd_names['Emma'], emma_fd_names.freq('Emma')
# 전체 단어 수, emma 단어 출현 횟수, emma 단어 출현 확률
# Out:
# (7863, 830, 0.10555767518758744)

# %%
# 가장 출현 횟수가 높은 단어 상위 5개
emma_fd_names.most_common(5)
# Out:
# [('Emma', 830),
#  ('Harriet', 491),
#  ('Weston', 439),
#  ('Knightley', 389),
#  ('Elton', 385)]

# %% [markdown]
# ### 2.6 유튜브 댓글 분석하기

# %%
import pandas as pd

comment_df = pd.read_csv('comment.csv', encoding='utf-8-sig')
comment_df.head()
# Out:
#          user                   comment
# 0    ramesh g  헬륨을 넣은 지수 목소리 너무 귀여웠어요 🤩
# 1  Ali Kaleli      Jensoo and chaelisaa
# 2  Ali Kaleli               roséé yeaah
# 3  Ali Kaleli             Jisoo unnie 😅
# 4  Ali Kaleli                   Oh..old

# %%
# 정규표현식을 이용한 토큰화 시행
from nltk.tokenize import RegexpTokenizer

ret = RegexpTokenizer('[\w]+')
comment_tokens = comment_df['comment'].map(ret.tokenize)
comment_tokens
# Out:
# 0                          [헬륨을, 넣은, 지수, 목소리, 너무, 귀여웠어요]
# 1                               [Jensoo, and, chaelisaa]
# 2                                         [roséé, yeaah]
# 3                                         [Jisoo, unnie]
# 4                                              [Oh, old]
#                              ...
# 189                           [rose, Lisa, love, 12, 19]
# 190                                [1, 55, 2, 21, 5, 25]
# 191                                [People, watch, this]
# 192                  [1, 04, roseye, bakkkkk, hahahhaaa]
# 193    [My, mouth, is, watering, while, seeing, rose,...
# Name: comment, Length: 194, dtype: object

# %%
# 품사 태깅
from nltk.tag import pos_tag

comment_tags = comment_tokens.map(pos_tag)
comment_tags
# Out:
# 0      [(헬륨을, JJ), (넣은, NNP), (지수, NNP), (목소리, NNP), ...
# 1            [(Jensoo, NNP), (and, CC), (chaelisaa, NN)]
# 2                             [(roséé, NN), (yeaah, NN)]
# 3                            [(Jisoo, NNP), (unnie, NN)]
# 4                                  [(Oh, UH), (old, JJ)]
#                              ...
# 189    [(rose, VBD), (Lisa, NNP), (love, VBD), (12, C...
# 190    [(1, CD), (55, CD), (2, CD), (21, CD), (5, CD)...
# 191            [(People, NNS), (watch, VBP), (this, DT)]
# 192    [(1, CD), (04, CD), (roseye, NN), (bakkkkk, NN...
# 193    [(My, PRP$), (mouth, NN), (is, VBZ), (watering...
# Name: comment, Length: 194, dtype: object

# %%
comment_list = comment_tags.values.tolist()
comment_list[:3]
# Out:
# [[('헬륨을', 'JJ'),
#   ('넣은', 'NNP'),
#   ('지수', 'NNP'),
#   ('목소리', 'NNP'),
#   ('너무', 'NNP'),
#   ('귀여웠어요', 'NN')],
#  [('Jensoo', 'NNP'), ('and', 'CC'), ('chaelisaa', 'NN')],
#  [('roséé', 'NN'), ('yeaah', 'NN')]]

# %%
# 2차원 리스트를 1차원으로 변환
from itertools import chain
comment_list = list(chain.from_iterable(comment_list))
comment_list[:3]
# Out:
# [('헬륨을', 'JJ'), ('넣은', 'NNP'), ('지수', 'NNP')]

# %%
# 정규표현식을 이용하여 명사만 추출
import re
pattern = re.compile('NN?')
comment_nouns = [t[0] for t in comment_list if pattern.match(t[1])]
comment_nouns[:5]
# Out:
# ['넣은', '지수', '목소리', '너무', '귀여웠어요']

# %%
# 소문자 변환
comment_nouns = [x.lower() for x in comment_nouns]
# comment_nouns = list(map(lambda x : x.lower(), comment_nouns))
comment_nouns[:7]
# Out:
# ['넣은', '지수', '목소리', '너무', '귀여웠어요', 'jensoo', 'chaelisaa']

# %%
# Text 객체 생성 후 빈도 수 그래프 시각화
from nltk import Text
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager, rc
font_fname = 'c:/windows/fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))

comment_text = Text(comment_nouns)
comment_text.plot(50)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 2.7 rss 서비스 주소 뉴스 크롤링

# %%
# jtbc의 뉴스 속보 수집해서 단어와 빈도수를 그래프로 표시
from bs4 import BeautifulSoup
import requests

rss_link = 'https://fs.jtbc.joins.com//RSS/newsflash.xml'
jtbc_news = requests.get(rss_link)

news_list = BeautifulSoup(jtbc_news.content, 'xml')

# %%
# title
title_list = news_list.select("item > title")
title_list = [title.text for title in title_list]

# %%
# description
desc_list = news_list.select("item > description")
desc_list = [desc.text for desc in desc_list]

# %%
import pandas as pd

news_df = pd.DataFrame({'title':title_list, 'desc':desc_list})
news_df.head()
# Out:
#                                 title  \
# 0   [윤석열 긴급 기자회견] 1월 5일 (수) JTBC 뉴스특보
# 1  '기상청 사람들' 박민영X송강, 연애세포 열일 유발 티저 공개
# 2        '가면토론회' 여야 대선주자 관련 살벌한 토론 예고
# 3     '한 사람만' 채송화 살인사건의 진범, 서연우 엄마였다!
# 4   2022 부동산 시장 전망…흔들 주요 변수 '대통령 선거'?
#
#                                                 desc
# 0   &middot; "모두 제 책임&hellip;가족과 관련 심려끼쳐 죄송"&midd...
# 1  '기상청 사람들: 사내연애 잔혹사 편'이 새해를 맞아 연애 세포를 열일하게 만드는 ...
# 2  어디서도 볼 수 없었던 '사이다 토론'이 펼쳐진다.오늘(5일) 밤 9시 첫 방송되는...
# 3  '한 사람만'의 미스터리를 관통하는 채송화 살인사건의 진범이 안은진이 아니었다는 사...
# 4   ■ 인용보도 시 프로그램명 'JTBC 아침&'을 밝혀주시기 바랍니다. 저작권은 J...

# %%
news_ret = RegexpTokenizer('[\w]{2,}')
news_tokens = news_df['desc'].map(news_ret.tokenize)

# %%
news_tags = news_tokens.map(pos_tag)
news_tags_list = news_tags.values.tolist()
news_tags_list = list(chain.from_iterable(news_tags_list))

import re
# 한글만 추출
kor_pattern = re.compile('[가-힣]+')

news_tags_list = [i for i in news_tags_list if kor_pattern.match(i[0])]

# %%
noun_pattern = re.compile('NN?')
news_noun_tags = [t[0] for t in news_tags_list if noun_pattern.match(t[1])]

# %%
from collections import Counter
news_count_dict = Counter(news_noun_tags)
news_count_list = sorted(news_count_dict.items(), key=lambda x:x[1], reverse=True)
news_count_list_over2 = [i for i in news_count_list if i[1] > 1]
news_count_list_over2
# Out:
# [('관련', 3),
#  ('아침', 3),
#  ('코로나', 3),
#  ('확진자', 3),
#  ('석탄', 3),
#  ('방역패스를', 3),
#  ('윤석열', 2),
#  ('사람들', 2),
#  ('토론', 2),
#  ('있습니다', 2),
#  ('기온이', 2),
#  ('하루', 2),
#  ('어린이집에서', 2),
#  ('최대', 2),
#  ('아니라', 2),
#  ('김건희', 2),
#  ('미술관', 2)]

# %%
# Text 객체 생성 후 빈도 수 그래프 시각화
from nltk import Text
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager, rc
font_fname = 'c:/windows/fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))

news_text = Text(news_noun_tags)
news_text.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## 3. KoNLPy 한글 자연어처리기

# %% [markdown]
# ### 3.6 품사 태깅

# %%
text = u"""아름답지만 다소 복잡하기도한 한국어는 전세계에서 13번째로 많이
사용되는 언어입니다."""

# %%
# 1. Hannanum
from konlpy.tag import Hannanum
han = Hannanum()

# 각 토큰에 대한 다양한 형태소 후보 반환
print(han.analyze(text))
# Out:
# [[[('아름답', 'paa'), ('지만', 'ecs')], [('아름답', 'paa'), ('지', 'ecs'), ('만', 'jxc')], [('아름답', 'paa'), ('지', 'ecx'), ('말', 'px'), ('ㄴ', 'etm')]], [[('다소', 'mag')], [('다소', 'ncn')]], [[('복잡하기도한', 'ncn')], [('복잡하기도한', 'nqq')]], [[('한국어', 'ncn'), ('는', 'jxc')]], [[('전세계', 'ncn'), ('에서', 'jca')], [('전세', 'ncn'), ('계', 'ncn'), ('에서', 'jca')], [('전', 'xp'), ('세계', 'ncn'), ('에서', 'jca')]], [[('13', 'nnc'), ('번', 'nbu'), ('째', 'xsnu'), ('로', 'jca')]], [[('많', 'paa'), ('이', 'xsa')], [('많이', 'mag')]], [], [[('사용', 'ncpa'), ('되', 'xsvn'), ('는', 'etm')]], [[('언어', 'ncn'), ('이', 'jp'), ('ㅂ니다', 'ef')]], [[('.', 'sf')], [('.', 'sy')]]]

# %%
# 형태소 분석 문구 반환
print(han.morphs(text))
# Out:
# ['아름답', '지만', '다소', '복잡하기도한', '한국어', '는', '전세계', '에서', '13번', '째', '로', '많', '이', '사용', '되', '는', '언어', '이', 'ㅂ니다', '.']

# %%
# 명사 추출
print(han.nouns(text))
# Out:
# ['복잡하기도한', '한국어', '전세계', '13번', '사용', '언어']

# %%
print(han.pos(text, ntags=22, flatten=True))
# Out:
# [('아름답', 'PA'), ('지만', 'EC'), ('다소', 'MA'), ('복잡하기도한', 'NC'), ('한국어', 'NC'), ('는', 'JX'), ('전세계', 'NC'), ('에서', 'JC'), ('13', 'NN'), ('번', 'NB'), ('째', 'XS'), ('로', 'JC'), ('많', 'PA'), ('이', 'XS'), ('사용', 'NC'), ('되', 'XS'), ('는', 'ET'), ('언어', 'NC'), ('이', 'JP'), ('ㅂ니다', 'EF'), ('.', 'SF')]

# %%
print(han.pos(text, ntags=22, flatten=False))
# Out:
# [[[('아름답', 'PA'), ('지만', 'EC')]], [[('다소', 'MA')]], [[('복잡하기도한', 'NC')]], [[('한국어', 'NC'), ('는', 'JX')]], [[('전세계', 'NC'), ('에서', 'JC')]], [[('13', 'NN'), ('번', 'NB'), ('째', 'XS'), ('로', 'JC')]], [[('많', 'PA'), ('이', 'XS')]], [], [[('사용', 'NC'), ('되', 'XS'), ('는', 'ET')]], [[('언어', 'NC'), ('이', 'JP'), ('ㅂ니다', 'EF')]], [[('.', 'SF')]]]

# %%
# 2. Kkma
from konlpy.tag import Kkma
kkma = Kkma()

print(kkma.morphs(text))
# Out:
# ['아름답', '지만', '다소', '복잡', '하', '기', '도', '한', '한국어', '는', '전세계', '에서', '13', '번째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다', '.']

# %%
print(kkma.nouns(text))
# Out:
# ['복잡', '한국어', '전세계', '13', '13번째', '번째', '사용', '언어']

# %%
print(kkma.pos(text))
# Out:
# [('아름답', 'VA'), ('지만', 'ECE'), ('다소', 'MAG'), ('복잡', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('한', 'MDN'), ('한국어', 'NNG'), ('는', 'JX'), ('전세계', 'NNG'), ('에서', 'JKM'), ('13', 'NR'), ('번째', 'NNB'), ('로', 'JKM'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF')]

# %%
# 3. Komoran
from konlpy.tag import Komoran
kom = Komoran()

print(kom.morphs(text))
# Out:
# ['아름답', '지만', '다소', '복잡', '하', '기', '도', '하', 'ㄴ', '한국어', '는', '전', '세계', '에서', '13', '번', '째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다', '.']

# %%
print(kom.nouns(text))
# Out:
# ['한국어', '전', '세계', '번', '사용', '언어']

# %%
print(kom.pos(text))
# Out:
# [('아름답', 'VA'), ('지만', 'EC'), ('다소', 'MAG'), ('복잡', 'XR'), ('하', 'XSA'), ('기', 'ETN'), ('도', 'JX'), ('하', 'VV'), ('ㄴ', 'ETM'), ('한국어', 'NNP'), ('는', 'JX'), ('전', 'NNG'), ('세계', 'NNG'), ('에서', 'JKB'), ('13', 'SN'), ('번', 'NNB'), ('째', 'XSN'), ('로', 'JKB'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETM'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EF'), ('.', 'SF')]

# %% [markdown]
# ### 3.7 말뭉치

# %% [markdown]
# ## 4. 워드클라우드

# %% [markdown]
# ### 4.1 한국 법률 말뭉치를 이용한 워드클라우드 표시하기

# %%
from konlpy.corpus import kolaw
data = kolaw.open('constitution.txt').read()

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
print(komoran.nouns("%r" % data[0:1000]))
# Out:
# ['대한민국', '헌법', '유구', '한', '역사', '전통', '국민', '운동', '건립', '대한민국', '임시', '정부', '법통', '불의', '항거', '민주', '이념', '계승', '조국', '민주개혁', '평화', '통일', '사명', '입각', '정의', '인도', '동포애', '민족', '단결', '사회', '폐습', '불의', '타파', '자율', '조화', '바탕', '자유', '민주', '기본', '질서', '정치', '경제', '사회', '문화', '영역', '각인', '기회', '능력', '최고', '도로', '발휘', '자유', '권리', '책임', '의무', '완수', '안', '국민', '생활', '균등', '향상', '밖', '항구', '세계', '평화', '인류', '공영', '이바지', '우리들의', '자손', '안전', '자유', '행복', '확보', '것', '다짐', '년', '7월 12일', '제정', '차', '개정', '헌법', '국회', '의결', '국민', '투표', '개정', '장', '강', '대한민국', '민주공화국', '대한민국', '주권', '국민', '권력', '국민', '대한민국', '국민', '요건', '법률', '국가', '법률', '바', '재외국민', '보호', '의무', '대한민국', '영토', '한반도', '부속', '도서', '대한민국', '통일', '지향', '자유', '민주', '기본', '질서', '입각', '평화', '통일', '정책', '수립', '추진', '대한민국', '국제', '평화', '유지', '노력', '침략', '전쟁', '부인', '국군', '국가', '안전', '보장', '국토방위', '신성', '의무', '수행', '사명', '정치', '중립', '준수', '헌법', '체결', '공포', '조약', '일반', '승인', '국제', '법규', '국내법', '효력', '외국인', '국제법', '조약', '바', '지위', '보장', '공무원', '국민
# ...

# %%
word_list = komoran.nouns('%r'%data[0:1000])
text = ' '.join(word_list)
text
# Out:
# '대한민국 헌법 유구 한 역사 전통 국민 운동 건립 대한민국 임시 정부 법통 불의 항거 민주 이념 계승 조국 민주개혁 평화 통일 사명 입각 정의 인도 동포애 민족 단결 사회 폐습 불의 타파 자율 조화 바탕 자유 민주 기본 질서 정치 경제 사회 문화 영역 각인 기회 능력 최고 도로 발휘 자유 권리 책임 의무 완수 안 국민 생활 균등 향상 밖 항구 세계 평화 인류 공영 이바지 우리들의 자손 안전 자유 행복 확보 것 다짐 년 7월 12일 제정 차 개정 헌법 국회 의결 국민 투표 개정 장 강 대한민국 민주공화국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가 법률 바 재외국민 보호 의무 대한민국 영토 한반도 부속 도서 대한민국 통일 지향 자유 민주 기본 질서 입각 평화 통일 정책 수립 추진 대한민국 국제 평화 유지 노력 침략 전쟁 부인 국군 국가 안전 보장 국토방위 신성 의무 수행 사명 정치 중립 준수 헌법 체결 공포 조약 일반 승인 국제 법규 국내법 효력 외국인 국제법 조약 바 지위 보장 공무원 국민 전체 봉사자 국민 책임 공무원 신분 정치 중립 법률 바 보장 정당 설립 자유 복수 정당'

# %%
from wordcloud import WordCloud

wordc = WordCloud()
wordc.generate(text)

# %%
import matplotlib.pyplot as plt

plt.imshow(wordc)
plt.show()

# %% [markdown]
# ### 4.2 한글 처리

# %%
wordc = WordCloud(background_color='white', max_words=20, font_path=r'C:\Windows\Fonts\malgun.ttf', relative_scaling=0.2)
wordc.generate(text)

# %%
plt.imshow(wordc)
plt.axis('off') # 워드클라우드의 축 눈금과 레이블을 표시 안함
plt.show()

# %% [markdown]
# ### 4.3 전체 데이터를 이용한 워드클라우드 생성

# %%
word_list = komoran.nouns('%r'%data)
text = ' '.join(word_list)

wordcloud = WordCloud(background_color='white', max_words=2000, font_path='c:/Windows/Fonts/malgun.ttf', relative_scaling=0.2)
wordcloud.generate(text)

plt.figure(figsize=(15, 10))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### 4.4 불용어 사전 추가

# %%
from wordcloud import STOPWORDS
from sklearn.feature_extraction._stop_words import ENGLISH_STOP_WORDS

stop_w = STOPWORDS | ENGLISH_STOP_WORDS | {'대통령', '국가'}

# %% [markdown]
# ## 5. 연습문제

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.yonhapnewstv.co.kr/category/news/politics/feed/'

yh_news = requests.get(url)
yh_news_list = BeautifulSoup(yh_news.content, 'xml')

# %%
yh_title_list = yh_news_list.select('item > title')
yh_title_list = [i.text for i in yh_title_list]
yh_title_list
# Out:
# ['북, 자강도서 탄도미사일 추정체 발사…정부 "우려"',
#  '[여의도펀치] 민주당 전재수·국민의힘 성일종 한판 토론',
#  "[대선상황실] 대선 두달 앞두고 '킹메이커' 김종인과 결별…윤석열의 시간",
#  '[현장의재구성] 윤석열 주춤한 사이 달리려는 이재명',
#  '[여의도1번지] 이재명, 이낙연과 광주행…윤석열, 선대위 전격 해산',
#  '[대선 말말말] "\'별의 순간\'에 이런 사태"…"천지개벽 같은 것이 지지율"',
#  '북, 자강도서 탄도미사일 추정체 발사…정부 "우려"',
#  '윤, 선대위 해산 "다시 시작"…이, 이낙연과 광주행',
#  '주한중국대사 "올림픽 한국 대표단, 누가 와도 환영"',
#  '[정치+] 윤석열 "선대위 해산"…이재명, 이낙연과 광주행']

# %%
yh_desc_list = yh_news_list.select('item > description')
yh_desc_list = [i.text for i in yh_desc_list]

# %%
from konlpy.tag import Komoran
kom = Komoran()

yh_desc_text = ' '.join(yh_desc_list)
yh_noun_list = kom.nouns(yh_desc_text)

# %%
from wordcloud import STOPWORDS
from sklearn.feature_extraction._stop_words import ENGLISH_STOP_WORDS

stop_w = {"연합뉴스", "연합", "기사문의", "문의", "앵커", "기자", "뉴스", "제보", "닫기", 
                                            "기사", "보도", "라인", "오늘", "시간"}

# %%
import numpy as np
from PIL import Image
img = Image.open("south_korea.png").convert("RGBA")
mask_ar = np.array(img)

# %%
wordcloud = WordCloud(background_color='white', max_words=1000,
font_path='C:/Windows/Fonts/malgun.ttf', stopwords=stop_w,
mask=mask_ar, random_state=42)
wordcloud.generate(text)
wordcloud.recolor(colormap='cubehelix_r')

# %%
plt.figure(figsize=(15, 10))
plt.imshow(wordc)
plt.axis("off")
plt.show()
